# %% [markdown]
# **In this assignment students have to transform iris data into 3 dimensions
# and plot a 3d chart with transformed dimensions and colour each data
# point with specific class**|

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn import decomposition
from sklearn import datasets

# %%
df=datasets.load_iris()

# %%
X=df.data
y=df.target

# %% [markdown]
# **We will use PCA for reducing no of dimensions into 3**

# %%
from sklearn.decomposition import PCA
import pandas as pd
pca=PCA(n_components=3)
principal_components=pca.fit_transform(X)
principal_df=pd.DataFrame(data=principal_components,columns=["pc1","pc2","pc3"])

# %%
principal_df["species"]=y

# %%
principal_df
# Out:
#           pc1       pc2       pc3  species
# 0   -2.684126  0.319397 -0.027915        0
# 1   -2.714142 -0.177001 -0.210464        0
# 2   -2.888991 -0.144949  0.017900        0
# 3   -2.745343 -0.318299  0.031559        0
# 4   -2.728717  0.326755  0.090079        0
# ..        ...       ...       ...      ...
# 145  1.944110  0.187532  0.177825        2
# 146  1.527167 -0.375317 -0.121898        2
# 147  1.764346  0.078859  0.130482        2
# 148  1.900942  0.116628  0.723252        2
# 149  1.390189 -0.282661  0.362910        2
#
# [150 rows x 4 columns]

# %%
#now as we have our principal 3 components we can create our 3D plot

#creare a fig

fig=plt.figure(figsize=(10,10))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)

ax.set_title('3 component PCA', fontsize = 20)

targets=[0,1,2]
species = ['setosa','versicolor','virginica']
colors = ['r','g','b']


for target,color in zip(targets,colors):
    species_index=principal_df["species"]==target
    ax.scatter(principal_df.loc[species_index,"pc1"],
               principal_df.loc[species_index,"pc2"],
               principal_df.loc[species_index,"pc3"],c=color)
ax.legend(species)
ax.grid()
